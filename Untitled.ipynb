# %%
# importing package 
import matplotlib.pyplot as plt 
import pandas as pd 
  
# create data 
df = pd.DataFrame([['A', 10, 20, 10, 30], ['B', 20, 25, 15, 25], ['C', 12, 15, 19, 6], 
                   ['D', 10, 29, 13, 19]], 
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4']) 
# view data 
print(df) 
  
# plot grouped bar chart 
df.plot(x='Team', 
        kind='bar', 
        stacked=False, 
        title='Grouped Bar Graph with dataframe')
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       30
# 1    B       20       25       15       25
# 2    C       12       15       19        6
# 3    D       10       29       13       19
# <Axes: title={'center': 'Grouped Bar Graph with dataframe'}, xlabel='Team'>

# %%
import pandas as pd

# Assume we have the following DataFrame from the previous answer
grouped_dict = {
    'A': ['foo', 'foo', 'bar', 'bar'],
    'B': ['one', 'two', 'one', 'two'],
    'C': [1, 2, 3, 4],
    'D': [10, 20, 30, 40]
}

df = pd.DataFrame(grouped_dict)

# Group the DataFrame by columns 'A' and 'B'
grouped = df.groupby(['A', 'B'])

# Now you can perform various operations on the grouped data
print(grouped.sum())
# Out:
#          C   D
# A   B
# bar one  3  30
#     two  4  40
# foo one  1  10
#     two  2  20
